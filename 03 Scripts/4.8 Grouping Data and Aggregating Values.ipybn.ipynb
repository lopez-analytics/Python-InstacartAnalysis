# %% [markdown]
# ## 01. Import libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Turn Project Folder into Path
path = r'/Users/tanayawinder/Desktop/6-27-2024 Instant Cart Basket Analysis'

# %%
# Import merged pickle file

opm_derived = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merged_derived.pkl'))

# %%
# Check output

opm_derived.shape
# Out:
# (32404859, 17)

# %%
opm_derived.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %% [markdown]
# ### Find aggregated mean of 'number_of_orders' col grouped by 'department_id' for entire dataset¶

# %%
# Groupby on ords_prods_merge 'department_id', aggregate mean # of orders

opm_derived.groupby('department_id').agg({'number_of_orders':['mean']})
# Out:
#               number_of_orders
#                           mean
# department_id
# 1                    15.457838
# 2                    17.277920
# 3                    17.170395
# 4                    17.811403
# 5                    15.215751
# 6                    16.439806
# 7                    17.225802
# 8                    15.340650
# 9                    15.895474
# 10                   20.197148
# 11                   16.170638
# 12                   15.887671
# 13                   16.583536
# 14                   16.773669
# 15                   16.165037
# 16                   17.665606
# 17                   15.694469
# 18                   19.310397
# 19                   17.177343
# 20                   16.473447
# 21                   22.902379

# %% [markdown]
# A few things are different about the output of this aggregation on the entire dataset vs on the subset (in Exercise). Some of the values are different, such as Produce (4). In the subset it has a mean of 18.83, in the whole dataframe the mean is 17.81. We are also only presented the rows that appear on record in the subset (and as they appear, not in chronological order), whereas we are guaranteed all departments if aggregating the entire dataset.

# %% [markdown]
# ### Create a loyalty flag for existing customers using the transform() and loc() functions

# %%
# Groupby on dataset by user_id, apply transform() on the “number_of_orders" col to generate max orders per user

opm_derived['max_order'] =  opm_derived.groupby(['user_id'])['number_of_orders'].transform(np.max)
# Out:
# /var/folders/tx/v4zzzx0x7735_gq8qjd1ddj00000gn/T/ipykernel_52589/3716214790.py:3: FutureWarning: The provided callable <function max at 0x109a042c0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   opm_derived['max_order'] =  opm_derived.groupby(['user_id'])['number_of_orders'].transform(np.max)

# %%
opm_derived.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
opm_derived.shape
# Out:
# (32404859, 18)

# %%
# Use new max_orders col to create loyalty flag

opm_derived.loc[opm_derived['max_order'] > 40, 'loyalty_flag'] =  'Loyal customer'

# %%
opm_derived.loc[(opm_derived['max_order'] <= 40) & (opm_derived['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
opm_derived.loc[opm_derived['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check output

opm_derived.shape
# Out:
# (32404859, 19)

# %%
opm_derived.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
opm_derived['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %% [markdown]
# ### Determine whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Aggregate mean, min, max of prices of products by loyalty category

opm_derived.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ### Create 'type_of_spender' col to target different customers in marketing campaigns

# %%
# Create avg_spend col

opm_derived['avg_spend'] = opm_derived.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/tx/v4zzzx0x7735_gq8qjd1ddj00000gn/T/ipykernel_52589/2196032372.py:3: FutureWarning: The provided callable <function mean at 0x109a04cc0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   opm_derived['avg_spend'] = opm_derived.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check output

opm_derived.shape
# Out:
# (32404859, 20)

# %%
opm_derived.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %%
# Create spender flag

opm_derived.loc[opm_derived['avg_spend']<10,'spender_flag']='Low_spender'

# %%
opm_derived.loc[opm_derived['avg_spend']>= 10, 'spender_flag'] = 'High_spender'

# %%
# Check spender flag output

opm_derived['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     31770614
# High_spender      634245
# Name: count, dtype: int64

# %%
opm_derived[['user_id', 'avg_spend', 'spender_flag', 'prices']].head(60)
# Out:
#     user_id  avg_spend spender_flag  prices
# 0         1   6.367797  Low_spender     9.0
# 1         1   6.367797  Low_spender     9.0
# 2         1   6.367797  Low_spender     9.0
# 3         1   6.367797  Low_spender     9.0
# 4         1   6.367797  Low_spender     9.0
# 5         1   6.367797  Low_spender     9.0
# 6         1   6.367797  Low_spender     9.0
# 7         1   6.367797  Low_spender     9.0
# 8         1   6.367797  Low_spender     9.0
# 9         1   6.367797  Low_spender     9.0
# 10       15   3.980556  Low_spender     9.0
# 11       15   3.980556  Low_spender     9.0
# 12       15   3.980556  Low_spender     9.0
# 13       15   3.980556  Low_spender     9.0
# 14       15   3.980556  Low_spender     9.0
# 15       19   8.372059  Low_spender     9.0
# 16       19   8.372059  Low_spender     9.0
# 17       19   8.372059  Low_spender     9.0
# 18       21   7.012683  Low_spender     9.0
# 19       31   8.137793  Low_spender     9.0
# ...

# %% [markdown]
# ### Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column.¶

# %%
# Create a frequent user col, Groupyby user_id, aggreagate days_since_prior_order median

opm_derived['customer_frequency'] = opm_derived.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# /var/folders/tx/v4zzzx0x7735_gq8qjd1ddj00000gn/T/ipykernel_52589/2886579926.py:3: FutureWarning: The provided callable <function median at 0x109b41da0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   opm_derived['customer_frequency'] = opm_derived.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check output

opm_derived.head(50)
# Out:
#     order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0    2539329        1                 1                  2                  8
# 1    2398795        1                 2                  3                  7
# 2     473747        1                 3                  3                 12
# 3    2254736        1                 4                  4                  7
# 4     431534        1                 5                  4                 15
# 5    3367565        1                 6                  2                  7
# 6     550135        1                 7                  1                  9
# 7    3108588        1                 8                  1                 14
# 8    2295261        1                 9                  1                 16
# 9    2550362        1                10                  4                  8
# 10   2968173       15                15                  1                  9
# ...

# %%
opm_derived.shape
# Out:
# (32404859, 22)

# %%
# Create customer frequency flag

opm_derived.loc[opm_derived['customer_frequency'] > 20, 'frequency_flag'] = 'Non-frequent Customer'

# %%
opm_derived.loc[(opm_derived['customer_frequency']>10) & (opm_derived['customer_frequency']<=20),'frequency_flag'] = 'Regular customer'

# %%
opm_derived.loc[opm_derived['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
# Check flag output
opm_derived['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent Customer        21559853
# Regular customer          7208564
# Non-frequent Customer     3636437
# nan                             5
# Name: count, dtype: int64

# %%
opm_derived[['user_id', 'customer_frequency', 'frequency_flag']].head(50)
# Out:
#     user_id  customer_frequency         frequency_flag
# 0         1                20.5  Non-frequent Customer
# 1         1                20.5  Non-frequent Customer
# 2         1                20.5  Non-frequent Customer
# 3         1                20.5  Non-frequent Customer
# 4         1                20.5  Non-frequent Customer
# 5         1                20.5  Non-frequent Customer
# 6         1                20.5  Non-frequent Customer
# 7         1                20.5  Non-frequent Customer
# 8         1                20.5  Non-frequent Customer
# 9         1                20.5  Non-frequent Customer
# 10       15                10.0      Frequent Customer
# 11       15                10.0      Frequent Customer
# 12       15                10.0      Frequent Customer
# 13       15                10.0      Frequent Customer
# 14       15                10.0      Frequent Customer
# 15       19                 6.0      Frequent Customer
# ...

# %% [markdown]
# ### Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Export file as pickle

opm_derived.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'aggregated_ords_prods_merge.pkl'))
